# %%
# %pip install faker
# Out:
# Requirement already satisfied: faker in c:\projects\notebook-frameworks\venv\lib\site-packages (37.0.0)
# Requirement already satisfied: tzdata in c:\projects\notebook-frameworks\venv\lib\site-packages (from faker) (2024.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from faker import Faker
import pandas as pd
from random import randrange

fake = Faker()
output = [{
        "name": fake.name(),
        "address": fake.address(),
        "city": fake.city(),
        "state": fake.state(),
        "email": fake.email(),
        "age": 10 + randrange(70)
    } for _ in range(100)]
df = pd.DataFrame(output)
df
# Out:
#                name                                            address  \
# 0      Sheryl Davis  015 Fischer Extensions Suite 288\nVincentside,...
# 1    Margaret Lopez  79572 Emily Forges Apt. 146\nEast Jonathanside...
# 2      Joseph Nixon           720 Bryant Avenue\nAndrewmouth, AZ 13491
# 3   Elaine Mcdonald  776 Lopez Drive Apt. 776\nNorth Annafort, NH 6...
# 4     Ellen Bernard           164 Ibarra Courts\nSpencerside, VT 54277
# ..              ...                                                ...
# 95      Jodi Powell                  115 Guy Drive\nYangfurt, MH 65473
# 96    Ethan Ramirez  8759 Payne Loaf Suite 541\nPort Kimberly, AR 3...
# 97       Erin Moore           3009 Tiffany Point\nWest Laura, PR 59726
# 98      Joshua Diaz     201 Lopez Place Suite 050\nWebbmouth, AZ 36187
# 99       Amy Nelson     1261 Vanessa Ridge\nNorth Alexisbury, TX 71788
#
#                  city     state                        email  age
# 0        Waltersville  Arkansas           adam88@example.org   41
# 1        Atkinsonstad   Vermont     osbornebryan@example.org   63
# 2         Timothyview      Iowa   russellstephen@example.net   63
# 3         Garrettport    Hawaii  turnerchristina@example.net   47
# 4           Davidview   Vermont           mewing@example.com   34
# ..                ...       ...                          ...  ...
# 95     South Charlene  New York          andre90@example.org   44
# 96  North Christopher     Maine        abigail83@example.com   17
# 97  South Michaelberg      Ohio    larrythompson@example.com   48
# 98         New Ashley  Virginia        michael58@example.com   36
# 99    New Timothystad  Delaware        brendan43@example.com   14
#
# [100 rows x 6 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

df.hist(column="age", bins=10)
plt.show()
