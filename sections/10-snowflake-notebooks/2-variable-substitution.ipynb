# %% [markdown]
# ### Python to SQL

# %%
var1 = 'Wonderful'

# %%
select '{{var1}}'

# %% [markdown]
# ### SQL to SQL

# %%
select *
from snowflake_sample_data.tpch_sf1.customer
limit 10

# %%
select c_name from {{cell2}} limit 3

# %% [markdown]
# ### SQL to Python

# %%
df = cell3.to_pandas()
df
